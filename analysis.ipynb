# %%
import os
import torch

target_device = "cpu"

# %%
os.getcwd()
# Out:
# '/home/eingerman/Projects/TTS/VibeVoice'

# %%
voice = torch.load("demo/voices/streaming_model/en-Carter_man.pt", map_location=target_device, weights_only=False)

# %%
voice['neg_tts_lm']
# Out:
# BaseModelOutputWithPast(last_hidden_state=tensor([[[ 1.0625e+00, -1.6484e+00,  8.9062e-01,  6.6406e-01,  6.3281e-01,
#            2.8711e-01,  1.1328e+00, -1.4844e+00,  1.0781e+00,  2.6758e-01,
#            8.2812e-01,  8.1543e-02, -2.2754e-01,  4.5117e-01, -5.5859e-01,
#           -1.6484e+00, -8.5547e-01,  1.1094e+00,  2.0938e+00, -4.9062e+00,
#            2.1562e+00, -1.6875e+00, -1.4688e+00, -1.2969e+00,  8.9844e-01,
#            1.8359e+00,  4.4141e-01, -1.2344e+00,  2.6367e-01, -5.5859e-01,
#           -1.6484e+00, -9.5312e-01,  1.1328e+00, -1.6250e+00, -6.0547e-02,
#            2.6719e+00,  8.6426e-02,  7.3438e-01,  2.4688e+00, -3.3203e-01,
#            2.1094e+00,  1.0938e+00,  6.4453e-01,  2.7031e+00,  3.2812e-01,
#            3.5625e+00,  2.3906e+00, -3.1836e-01,  1.5938e+00,  8.8281e-01,
#           -2.1094e+00,  2.5977e-01,  1.1016e+00,  6.5312e+00,  1.5703e+00,
#           -2.8438e+00, -1.8594e+00, -1.3438e+00,  2.1562e+00,  2.3594e+00,
# ...

# %%
from safetensors.torch import load_file

model = load_file("model/model.safetensors")

# %%
model.keys()
# Out:
# dict_keys(['model.acoustic_connector.fc1.bias', 'model.acoustic_connector.fc1.weight', 'model.acoustic_connector.fc2.bias', 'model.acoustic_connector.fc2.weight', 'model.acoustic_connector.norm.weight', 'model.acoustic_tokenizer.decoder.head.conv.conv.bias', 'model.acoustic_tokenizer.decoder.head.conv.conv.weight', 'model.acoustic_tokenizer.decoder.stages.0.0.ffn.linear1.bias', 'model.acoustic_tokenizer.decoder.stages.0.0.ffn.linear1.weight', 'model.acoustic_tokenizer.decoder.stages.0.0.ffn.linear2.bias', 'model.acoustic_tokenizer.decoder.stages.0.0.ffn.linear2.weight', 'model.acoustic_tokenizer.decoder.stages.0.0.ffn_gamma', 'model.acoustic_tokenizer.decoder.stages.0.0.ffn_norm.weight', 'model.acoustic_tokenizer.decoder.stages.0.0.gamma', 'model.acoustic_tokenizer.decoder.stages.0.0.mixer.conv.conv.conv.bias', 'model.acoustic_tokenizer.decoder.stages.0.0.mixer.conv.conv.conv.weight', 'model.acoustic_tokenizer.decoder.stages.0.0.norm.weight', 'model.acoustic_tokenizer.decoder.stages.
# ...
